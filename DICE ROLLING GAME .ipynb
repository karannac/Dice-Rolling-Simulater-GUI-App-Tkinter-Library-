# %%
import random 
from tkinter import *

# %%
def roll():
    a = random.randint(1, 6)
    return a 

root = Tk()
root.title('Dice Roll Game')
root.geometry('550x550')
root.configure(background = 'pink')

p1 = Label(root, text = 'Player 1', bg = 'blue', fg = 'white', padx = 5, pady = 5)
p1.place(relx = 0.05, rely = 0.05, anchor = CENTER)

p2 = Label(root, text = 'Player 2', bg = 'blue', fg = 'white', padx = 5, pady = 5)
p2.place(relx =0.05 , rely = 0.11, anchor = CENTER)

r = Entry(root)
r.place(x = 60, y = 20)

t = Entry(root)
t.place(x = 60, y = 52)



#FUNCTONS 

def inp_1():
    global f_inp 
    d = roll()
    f_inp = int(d)
    e = Label(root, text = d, fg = 'black', bg = 'pink', padx = 5, pady = 5)
    e.place(x = 95, y = 345)
    
    
def inp_2():
    global s_inp 
    w = roll()
    s_inp = int(w)
    i = Label(root, text = w, fg = 'black', bg = 'pink', padx = 5, pady = 5)
    i.place(x = 480, y = 345)
        
def compare():
    result.delete(0, END)
    if f_inp == s_inp:
        result.insert(END, 'ITS A DRAW')
    elif f_inp > s_inp:
        result.insert(END, r.get() + 'WINSSS...')
    else:
        result.insert(END , t.get() + 'WINSSS...')
    
def rou():
    #while rounds != 6:
        rou_entry.insert(END, rounds)
        rounds = rou_entry.get() + 1 
    
    
        
    
# BUTTONS 

mybutton_1 = Button(root, text = 'Player 1...Rool dice here', command = inp_1, bg = 'purple', fg = 'white')
mybutton_1.place(relx = 0.15, rely = 0.6, anchor = CENTER)


mybutton_2 = Button(root, text = 'Player 2...Rool dice here', command = inp_2, bg = 'purple', fg = 'white')
mybutton_2.place(relx = 0.85, rely = 0.6, anchor = CENTER)


res = Label(root, text = 'RESULTS ', fg = 'RED')
res.place(relx = 0.5, rely = 0.40, anchor = CENTER)

display = Button(root, text = 'SCORE: ', command = compare, bg = 'black', fg = 'white')
display.place(relx = 0.5, rely = 0.45, anchor = CENTER)

result = Entry(bg = 'red', fg = 'white', borderwidth = 2)
result.place(relx = 0.5, rely = 0.50, anchor = CENTER)

rou_buuton = Button(root, text = 'ROU', command = rou )
rou_buuton.place(x = 50, y = 500)

rounds = Label(root, text = 'Rounds:')
rounds.place(x = 200, y = 150)

rou_entry = Entry(root)
rou_entry.place(x = 255, y = 150 )

value_1 = Label(root, text = 'Dice Value')
value_1.place(x = 17 , y = 349)

value_2 = Label(root, text = 'Dice Value')
value_2.place(x = 400, y = 349)


root.mainloop()
